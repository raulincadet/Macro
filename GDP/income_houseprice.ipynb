# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
dhpi1=pd.read_excel("HPI_PO_state.xls")
dhpi1.head(4)
# Out:
#   state    yr  qtr  index_nsa  index_sa  \
# 0    AK  1991    1     100.00    100.00
# 1    AK  1991    2     100.79    100.08
# 2    AK  1991    3     102.08    101.32
# 3    AK  1991    4     102.24    102.23
#
#                                              Warning
# 0  * Note that this state has fewer than 15,000 t...
# 1  * Note that this state has fewer than 15,000 t...
# 2  * Note that this state has fewer than 15,000 t...
# 3  * Note that this state has fewer than 15,000 t...

# %%
dhpi=dhpi1[(dhpi1.yr==2023) &(dhpi1.qtr==3)]
dhpi=dhpi.reset_index()
dhpi
# Out:
#     index state    yr  qtr  index_nsa  index_sa  \
# 0     130    AK  2023    3     358.21    352.08
# 1     261    AL  2023    3     354.76    350.74
# 2     392    AR  2023    3     347.20    344.91
# 3     523    AZ  2023    3     558.45    553.24
# 4     654    CA  2023    3     414.91    412.64
# 5     785    CO  2023    3     689.00    684.92
# 6     916    CT  2023    3     273.31    270.31
# 7    1047    DC  2023    3     633.23    627.35
# 8    1178    DE  2023    3     310.10    309.99
# 9    1309    FL  2023    3     554.11    548.58
# 10   1440    GA  2023    3     408.78    405.79
# 11   1571    HI  2023    3     375.40    373.69
# 12   1702    IA  2023    3     352.28    346.81
# 13   1833    ID  2023    3     619.67    611.71
# 14   1964    IL  2023    3     288.23    284.30
# 15   2095    IN  2023    3     339.54    335.16
# 16   2226    KS  2023    3     379.83    374.60
# 17   2357    KY  2023    3     367.74    366.49
# 18   2488    LA  2023    3     362.18    358.30
# 19   2619    MA  2023    3     439.94    435.33
# 20   2750    MD  2023    3     353.38    350.47
# 21   2881    ME  2023    3     459.28    455.05
# 22   3012    MI  2023    3     356.85    351.27
# 23   3143    MN  2023    3     411.94    407.46
# 24   3274    MO  2023    3     375.04    370.94
# 25   3405    MS  2023    3     303.97    302.89
# 26   3536    MT  2023    3     687.18    685.37
# 27   3667    NC  2023    3     421.91    418.79
# 28   3798    ND  2023    3     409.98    405.39
# 29   3929    NE  2023    3     408.03    403.28
# 30   4060    NH  2023    3     432.03    431.35
# 31   4191    NJ  2023    3     375.43    373.41
# 32   4322    NM  2023    3     387.34    382.24
# 33   4453    NV  2023    3     400.42    393.90
# 34   4584    NY  2023    3     376.45    371.23
# 35   4715    OH  2023    3     322.01    317.79
# 36   4846    OK  2023    3     366.20    363.28
# 37   4977    OR  2023    3     627.43    622.10
# 38   5108    PA  2023    3     342.76    339.68
# 39   5239    RI  2023    3     385.83    381.73
# 40   5370    SC  2023    3     413.95    409.97
# 41   5501    SD  2023    3     474.26    470.15
# 42   5632    TN  2023    3     454.82    451.97
# 43   5763    TX  2023    3     443.82    439.42
# 44   5894    UT  2023    3     699.75    693.40
# 45   6025    VA  2023    3     391.36    389.31
# 46   6156    VT  2023    3     411.44    401.56
# 47   6287    WA  2023    3     573.07    566.81
# 48   6418    WI  2023    3     414.90    408.91
# 49   6549    WV  2023    3     310.90    305.94
# 50   6680    WY  2023    3     520.35    512.52
#
#                                               Warning
# 0   * Note that this state has fewer than 15,000 t...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   * Note that this state has fewer than 15,000 t...
# 8   * Note that this state has fewer than 15,000 t...
# 9                                                 NaN
# 10                                                NaN
# 11  * Note that this state has fewer than 15,000 t...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46  * Note that this state has fewer than 15,000 t...
# 47                                                NaN
# 48                                                NaN
# 49  * Note that this state has fewer than 15,000 t...
# 50                                                NaN

# %%
df_inc=pd.read_csv('SQINC4__ALL_AREAS_1948_2023 (2).csv')

# Select rows related to Personal income
df_inc1=df_inc[df_inc.Description=='Personal income (millions of dollars, seasonally adjusted) ']
df_inc1=df_inc1.reset_index()
df_inc1.head(3)
# Out:
#    index   GeoFIPS        GeoName Region TableName  LineCode  \
# 0      0   "00000"  United States           SQINC4      10.0
# 1     20   "01000"        Alabama      5    SQINC4      10.0
# 2     40   "02000"       Alaska *      8    SQINC4      10.0
#
#   IndustryClassification                                        Description  \
# 0                    ...  Personal income (millions of dollars, seasonal...
# 1                    ...  Personal income (millions of dollars, seasonal...
# 2                    ...  Personal income (millions of dollars, seasonal...
#
#                   Unit   1948:Q1  ...     2021:Q2     2021:Q3     2021:Q4  \
# 0  Millions of dollars  204641.7  ...  21031135.9  21124208.1  21268077.5
# 1  Millions of dollars    2496.0  ...    245905.6    247487.7    251181.2
# 2  Millions of dollars      (NA)  ...     47397.6     47485.1     48023.9
#
#       2022:Q1     2022:Q2     2022:Q3     2022:Q4     2023:Q1     2023:Q2  \
# 0  21395331.0  21640433.8  21995492.2  22249735.0  22618087.3  22842354.6
# 1    252387.8    255728.9    260858.5    264473.5    268653.7    269864.2
# 2     49140.4     50110.1     50838.0     51310.2     51223.7     51964.8
#
#       2023:Q3
# 0  23037613.4
# 1    271894.6
# 2     52251.5
#
# [3 rows x 312 columns]

# %%
dinc=pd.DataFrame({'States':df_inc1['GeoName'],'Income':df_inc1['2023:Q3']*1000000})
dinc=dinc.set_index('States')
dinc.head()
# Out:
#                      Income
# States
# United States  2.303761e+13
# Alabama        2.718946e+11
# Alaska *       5.225150e+10
# Arizona        4.614203e+11
# Arkansas       1.656221e+11

# %%
# correct states names where an * appear next to their names.
States=list()
for i in dinc.index:
    if '*' in i:
        states.append(i[:-1])
    else:
        States.append(i)
    
dinc.index=[i.strip() for i in States] # remove space in some states name
dinc.shape,dinc.head()
# Out:
# ((60, 1),
#                       Income
#  United States  2.303761e+13
#  Alabama        2.718946e+11
#  Alaska         5.225150e+10
#  Arizona        4.614203e+11
#  Arkansas       1.656221e+11)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the webpage containing the table
url = 'https://www.bu.edu/brand/guidelines/editorial-style/us-state-abbreviations/'

# Send a GET request to the webpage
response = requests.get(url)

# Parse the HTML content of the webpage
soup = BeautifulSoup(response.text, 'html.parser')

# Find the table 
table = soup.find('table')

# Convert the HTML table to a DataFrame
df_states = pd.read_html(str(table))[0]

df_states.head(4)
# Out:
#            0                         1              2
# 0  Full Name  Traditional Abbreviation  2-letter USPS
# 1    Alabama                      Ala.             AL
# 2     Alaska           Alaska or Alas.             AK
# 3   Arkansas                      Ark.             AR

# %%
df_states.columns=['States','Traditional abbreviation','state']
df_states=df_states.loc[1:,:]
df_states=df_states.set_index('States')
df_states=df_states[['state']]
df_states.head(4)
# Out:
#          state
# States
# Alabama     AL
# Alaska      AK
# Arkansas    AR
# Arizona     AZ

# %%
# Out:
# 'raul'

# %%
d3=pd.merge(dinc,df_states,left_index=True,right_index=True)
d3.shape
# Out:
# (51, 2)

# %%
df_pop=pd.read_excel('NST-EST2023-POP.xlsx',header=3,nrows=57) # Source: https://www.census.gov/data/tables/time-series/demo/popest/2020s-state-total.html
df_pop.columns=['States','Estimates base','Population 2020','Population 2021','Population 2022','Population 2023']
df_pop=df_pop.set_index('States') 
df_pop.head()
# Out:
#                Estimates base  Population 2020  Population 2021  \
# States
# United States       331464948        331526933        332048977
# Northeast            57614141         57430477         57243423
# Midwest              68987296         68969794         68850246
# South               126268529        126465281        127353282
# West                 78594982         78661381         78602026
#
#                Population 2022  Population 2023
# States
# United States        333271411        334914895
# Northeast             57026847         56983517
# Midwest               68783028         68909283
# South                128702030        130125290
# West                  78759506         78896805

# %%
# to remove the dot before some states names
z=list()
for i in df_pop.index:
    if '.' in i:
        z.append(i[1:])
    else:
        z.append(i)
    
df_pop.index=z

# df_pop=df_pop.reset_index()
# df_pop=df_pop.rename(columns={'index': 'States'})
# df_pop=df_pop.set_index('States')
df_pop.head(6)
# Out:
#                Estimates base  Population 2020  Population 2021  \
# United States       331464948        331526933        332048977
# Northeast            57614141         57430477         57243423
# Midwest              68987296         68969794         68850246
# South               126268529        126465281        127353282
# West                 78594982         78661381         78602026
# Alabama               5024294          5031864          5050380
#
#                Population 2022  Population 2023
# United States        333271411        334914895
# Northeast             57026847         56983517
# Midwest               68783028         68909283
# South                128702030        130125290
# West                  78759506         78896805
# Alabama                5073903          5108468

# %%
d4=pd.merge(d3,df_pop,left_index=True,right_index=True)
d4['Personnal income 2023Q3 (% population 2023)']=d4['Income']/d4['Population 2023']
d4.head(4)
# Out:
#                 Income state  Estimates base  Population 2020  \
# Alabama   2.718946e+11    AL         5024294          5031864
# Alaska    5.225150e+10    AK          733374           732964
# Arizona   4.614203e+11    AZ         7157902          7186683
# Arkansas  1.656221e+11    AR         3011490          3014348
#
#           Population 2021  Population 2022  Population 2023  \
# Alabama           5050380          5073903          5108468
# Alaska             734923           733276           733406
# Arizona           7272487          7365684          7431344
# Arkansas          3028443          3046404          3067732
#
#           Personnal income 2023Q3 (% population 2023)
# Alabama                                  53224.293467
# Alaska                                   71244.985724
# Arizona                                  62091.096846
# Arkansas                                 53988.451403

# %%
# Relate region to state data
df_geo=pd.read_excel('state-geocodes-v2014_modifyCRL.xlsx',sheet_name='Modify_Raulin')
df_geo=df_geo.set_index('States')
d5=pd.merge(d4,df_geo,left_index=True,right_index=True)
d5['region']=[i[:-7] for i in d5['Region']]

# %%
d6=pd.merge(d5,dhpi,on='state')
d6.head()
# Out:
#          Income state  Estimates base  Population 2020  Population 2021  \
# 0  2.718946e+11    AL         5024294          5031864          5050380
# 1  5.225150e+10    AK          733374           732964           734923
# 2  4.614203e+11    AZ         7157902          7186683          7272487
# 3  1.656221e+11    AR         3011490          3014348          3028443
# 4  3.151805e+12    CA        39538212         39503200         39145060
#
#    Population 2022  Population 2023  \
# 0          5073903          5108468
# 1           733276           733406
# 2          7365684          7431344
# 3          3046404          3067732
# 4         39040616         38965193
#
#    Personnal income 2023Q3 (% population 2023)        Region  \
# 0                                 53224.293467  South Region
# 1                                 71244.985724   West Region
# 2                                 62091.096846   West Region
# 3                                 53988.451403  South Region
# 4                                 80887.706626   West Region
#
#                       Division region  index    yr  qtr  index_nsa  index_sa  \
# 0  East South Central Division  South    261  2023    3     354.76    350.74
# 1             Pacific Division   West    130  2023    3     358.21    352.08
# 2            Mountain Division   West    523  2023    3     558.45    553.24
# 3  West South Central Division  South    392  2023    3     347.20    344.91
# 4             Pacific Division   West    654  2023    3     414.91    412.64
#
#                                              Warning
# 0                                                NaN
# 1  * Note that this state has fewer than 15,000 t...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ### Graphic

# %%
region_colors = {
    'Northeast': 'darkviolet',
    'Midwest': 'darkturquoise',    
    'South': 'green',      
    'West': 'saddlebrown',       
}

# regions=list(set(d5.region))  # list of regions
# colors = [region_colors[region] for region in regions]

# %%
fig=plt.subplot()
regionplotted=list()
for i in range(d6.shape[0]):
    if d6.loc[i,'region'] not in regionplotted:
        plt.scatter(x=d6.loc[i,'Personnal income 2023Q3 (% population 2023)'],y=d6.loc[i,'index_sa'],color=region_colors[d6.loc[i,'region']],label=d6.loc[i,'region'],alpha=0.65,s=90)
        regionplotted.append(d6.loc[i,'region'])
    else:
        plt.scatter(x=d6.loc[i,'Personnal income 2023Q3 (% population 2023)'],y=d6.loc[i,'index_sa'],color=region_colors[d6.loc[i,'region']],alpha=0.65,s=90)
    
    plt.text(x=d6.loc[i,'Personnal income 2023Q3 (% population 2023)']+750,y=d6.loc[i,'index_sa'],s=d6.loc[i,'state'])
plt.axvline(x=np.mean(d6['Personnal income 2023Q3 (% population 2023)']),color='red',linestyle='--')
plt.axhline(y=np.mean(d6['index_sa']),color='red',linestyle='--')
plt.xlabel('Personal income in USD')
plt.ylabel('House price index')
plt.title('House Price index (HPI) & Per Capita Personal Income\n by US States (2023 Quarter 3)',pad=55,size=14)
plt.gca().spines[['top','left','right','bottom']].set_visible(False)
plt.text(x=np.mean(d6['Personnal income 2023Q3 (% population 2023)'])*0.98,y=np.mean(d6['index_sa'])*0.62,color='red',s='Mean',rotation=90)
plt.text(x=np.min(d6['Personnal income 2023Q3 (% population 2023)']),y=np.mean(d6['index_sa'])*1.01,color='red',s='Mean HPI')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=len(region_colors))
plt.text(x=np.min(d6['Personnal income 2023Q3 (% population 2023)']),y=np.min(d6['index_sa'])-165,
         s="Source: By Raulin L. Cadet, with personal income data from the U.S.\n Bureau of Economic Analysis, House Price Index data from the Federal\n Housing Finance Agency. Population estimations, from the U.S. Census\n Bureau, is used to calculate per capita personal income.")
# Out:
# Text(48129.734767951726, 105.31, 'Source: By Raulin L. Cadet, with personal income data from the U.S.\n Bureau of Economic Analysis, House Price Index data from the Federal\n Housing Finance Agency. Population estimations, from the U.S. Census\n Bureau, is used to calculate per capita personal income.')
